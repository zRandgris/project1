# %% [markdown]
# ## Household final consumption expenditure

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib
import scipy.stats as stats
from scipy.stats import linregress
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Setting up pathway of data and reading it
csv_path = Path("Resource/123.csv")
df = pd.read_csv(csv_path)
df.head()
# Out:
#   REF_DATE     GEO           DGUID                  Prices  \
# 0  1961-01  Canada  2016A000011124  Chained (2012) dollars
# 1  1961-04  Canada  2016A000011124  Chained (2012) dollars
# 2  1961-07  Canada  2016A000011124  Chained (2012) dollars
# 3  1961-10  Canada  2016A000011124  Chained (2012) dollars
# 4  1962-01  Canada  2016A000011124  Chained (2012) dollars
#
#                    Seasonal adjustment  \
# 0  Seasonally adjusted at annual rates
# 1  Seasonally adjusted at annual rates
# 2  Seasonally adjusted at annual rates
# 3  Seasonally adjusted at annual rates
# 4  Seasonally adjusted at annual rates
#
#                                 Estimates      UOM  UOM_ID SCALAR_FACTOR  \
# 0  Food and non-alcoholic beverages [C11]  Dollars      81      millions
# 1  Food and non-alcoholic beverages [C11]  Dollars      81      millions
# 2  Food and non-alcoholic beverages [C11]  Dollars      81      millions
# 3  Food and non-alcoholic beverages [C11]  Dollars      81      millions
# 4  Food and non-alcoholic beverages [C11]  Dollars      81      millions
#
#    SCALAR_ID     VECTOR COORDINATE  VALUE  STATUS  SYMBOL  TERMINATED  \
# 0          6  v61988958    1.1.1.1  37146     NaN     NaN         NaN
# 1          6  v61988958    1.1.1.1  38476     NaN     NaN         NaN
# 2          6  v61988958    1.1.1.1  38871     NaN     NaN         NaN
# 3          6  v61988958    1.1.1.1  38446     NaN     NaN         NaN
# 4          6  v61988958    1.1.1.1  39497     NaN     NaN         NaN
#
#    DECIMALS
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Assume df is your DataFrame and 'date' is your column with dates
df['REF_DATE'] = pd.to_datetime(df['REF_DATE'], format='%Y-%m')

df["REF_YEAR"] = df["REF_DATE"].dt.year

clean_df = df.groupby(['REF_YEAR', 'Estimates']).sum()

# %%
#Resetting the index
clean_df.reset_index(inplace=True)

# %%
#Checking the data
clean_df
# Out:
#      REF_YEAR                                         Estimates  UOM_ID  \
# 0        1961  Alcoholic beverages,  tobacco and cannabis [C12]     324
# 1        1961                       Clothing and footwear [C13]     324
# 2        1961                              Communications [C18]     324
# 3        1961                                   Education [C21]     324
# 4        1961            Food and non-alcoholic beverages [C11]     324
# ..        ...                                               ...     ...
# 940      2023            Insurance and financial services [C23]      81
# 941      2023            Miscellaneous goods and services [C24]      81
# 942      2023                      Net expenditure abroad [C25]      81
# 943      2023                      Recreation and culture [C19]      81
# 944      2023                                   Transport [C17]      81
#
#      SCALAR_ID   VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# 0           24   59899     0.0     0.0         0.0         0
# 1           24   31637     0.0     0.0         0.0         0
# 2           24    4147     0.0     0.0         0.0         0
# 3           24    7312     0.0     0.0         0.0         0
# 4           24  152939     0.0     0.0         0.0         0
# ..         ...     ...     ...     ...         ...       ...
# 940          6  124753     0.0     0.0         0.0         0
# 941          6   64466     0.0     0.0         0.0         0
# 942          6    1504     0.0     0.0         0.0         0
# 943          6  104858     0.0     0.0         0.0         0
# 944          6  175774     0.0     0.0         0.0         0
#
# [945 rows x 9 columns]

# %% [markdown]
# # Setting up for Expenses over the years

# %%
#Delete extraneous coolumn-p
clean_df[["REF_YEAR","Estimates","VALUE"]].head(20)
# Out:
#     REF_YEAR                                          Estimates   VALUE
# 0       1961   Alcoholic beverages,  tobacco and cannabis [C12]   59899
# 1       1961                        Clothing and footwear [C13]   31637
# 2       1961                               Communications [C18]    4147
# 3       1961                                    Education [C21]    7312
# 4       1961             Food and non-alcoholic beverages [C11]  152939
# 5       1961    Food, beverage and accommodation services [C22]   84105
# 6       1961  Furnishings, household equipment and other goo...   33064
# 7       1961                                       Health [C16]   29625
# 8       1961        Household final consumption expenditure [C]  749193
# 9       1961  Housing, water, electricity, gas and other fue...  247124
# 10      1961             Insurance and financial services [C23]   33956
# 11      1961             Miscellaneous goods and services [C24]   33266
# 12      1961                       Net expenditure abroad [C25]   -4070
# 13      1961                       Recreation and culture [C19]   18676
# 14      1961                                    Transport [C17]   83298
# 15      1962   Alcoholic beverages,  tobacco and cannabis [C12]   63418
# 16      1962                        Clothing and footwear [C13]   33765
# 17      1962                               Communications [C18]    4418
# 18      1962                                    Education [C21]    7650
# 19      1962             Food and non-alcoholic beverages [C11]  158654

# %%
#rename the columns-p
rename_clean_df =clean_df.rename(columns={"REF_YEAR":"YEAR" , "Estimates": "Expenditures_(Millions_Dallars)"})
rename_clean_df
# Out:
#      YEAR                   Expenditures_(Millions_Dallars)  UOM_ID  \
# 0    1961  Alcoholic beverages,  tobacco and cannabis [C12]     324
# 1    1961                       Clothing and footwear [C13]     324
# 2    1961                              Communications [C18]     324
# 3    1961                                   Education [C21]     324
# 4    1961            Food and non-alcoholic beverages [C11]     324
# ..    ...                                               ...     ...
# 940  2023            Insurance and financial services [C23]      81
# 941  2023            Miscellaneous goods and services [C24]      81
# 942  2023                      Net expenditure abroad [C25]      81
# 943  2023                      Recreation and culture [C19]      81
# 944  2023                                   Transport [C17]      81
#
#      SCALAR_ID   VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# 0           24   59899     0.0     0.0         0.0         0
# 1           24   31637     0.0     0.0         0.0         0
# 2           24    4147     0.0     0.0         0.0         0
# 3           24    7312     0.0     0.0         0.0         0
# 4           24  152939     0.0     0.0         0.0         0
# ..         ...     ...     ...     ...         ...       ...
# 940          6  124753     0.0     0.0         0.0         0
# 941          6   64466     0.0     0.0         0.0         0
# 942          6    1504     0.0     0.0         0.0         0
# 943          6  104858     0.0     0.0         0.0         0
# 944          6  175774     0.0     0.0         0.0         0
#
# [945 rows x 9 columns]

# %%
#Delete extraneous coolumn-p
rename_clean_df[["YEAR","Expenditures_(Millions_Dallars)","VALUE"]].tail(20)
# Out:
#      YEAR                    Expenditures_(Millions_Dallars)    VALUE
# 925  2022             Insurance and financial services [C23]   509040
# 926  2022             Miscellaneous goods and services [C24]   255727
# 927  2022                       Net expenditure abroad [C25]      492
# 928  2022                       Recreation and culture [C19]   407300
# 929  2022                                    Transport [C17]   651906
# 930  2023   Alcoholic beverages,  tobacco and cannabis [C12]    42140
# 931  2023                        Clothing and footwear [C13]    59496
# 932  2023                               Communications [C18]    41002
# 933  2023                                    Education [C21]    20224
# 934  2023             Food and non-alcoholic beverages [C11]   106825
# 935  2023    Food, beverage and accommodation services [C22]    81599
# 936  2023  Furnishings, household equipment and other goo...    68777
# 937  2023                                       Health [C16]    53916
# 938  2023        Household final consumption expenditure [C]  1248630
# 939  2023  Housing, water, electricity, gas and other fue...   310225
# 940  2023             Insurance and financial services [C23]   124753
# 941  2023             Miscellaneous goods and services [C24]    64466
# 942  2023                       Net expenditure abroad [C25]     1504
# 943  2023                       Recreation and culture [C19]   104858
# 944  2023                                    Transport [C17]   175774

# %%
# Expense items-p
expense_items=rename_clean_df["Expenditures_(Millions_Dallars)"].unique()
expense_items
# Out:
# array(['Alcoholic beverages,  tobacco and cannabis [C12]',
#        'Clothing and footwear [C13]', 'Communications [C18]',
#        'Education [C21]', 'Food and non-alcoholic beverages [C11]',
#        'Food, beverage and accommodation services [C22]',
#        'Furnishings, household equipment and other goods and services related to the dwelling and property [C15]',
#        'Health [C16]', 'Household final consumption expenditure [C]',
#        'Housing, water, electricity, gas and other fuels [C14]',
#        'Insurance and financial services [C23]',
#        'Miscellaneous goods and services [C24]',
#        'Net expenditure abroad [C25]', 'Recreation and culture [C19]',
#        'Transport [C17]'], dtype=object)

# %% [markdown]
# Alchohol

# %%
#Alcoholic beverages,  tobacco and cannabis [C12]-p
Expenses_C12  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Alcoholic beverages,  tobacco and cannabis [C12]", ]
Expenses_C12[["YEAR","Expenditures_(Millions_Dallars)","VALUE"]]
# Out:
#      YEAR                   Expenditures_(Millions_Dallars)   VALUE
# 0    1961  Alcoholic beverages,  tobacco and cannabis [C12]   59899
# 15   1962  Alcoholic beverages,  tobacco and cannabis [C12]   63418
# 30   1963  Alcoholic beverages,  tobacco and cannabis [C12]   66918
# 45   1964  Alcoholic beverages,  tobacco and cannabis [C12]   69573
# 60   1965  Alcoholic beverages,  tobacco and cannabis [C12]   76114
# ..    ...                                               ...     ...
# 870  2019  Alcoholic beverages,  tobacco and cannabis [C12]  162677
# 885  2020  Alcoholic beverages,  tobacco and cannabis [C12]  171243
# 900  2021  Alcoholic beverages,  tobacco and cannabis [C12]  173929
# 915  2022  Alcoholic beverages,  tobacco and cannabis [C12]  171608
# 930  2023  Alcoholic beverages,  tobacco and cannabis [C12]   42140
#
# [63 rows x 3 columns]

# %%
# Plot graph :Alcoholic beverages,  tobacco and cannabis [C12]
Year_Expenses_C12 = Expenses_C12[["YEAR","VALUE"]]
Year_Expenses_C12=Year_Expenses_C12.set_index("YEAR")
Year_Expenses_C12= Year_Expenses_C12.rename(columns={"VALUE":"Alcoholic beverages_Value"})
Year_Expenses_C12
# Out:
#       Alcoholic beverages_Value
# YEAR
# 1961                      59899
# 1962                      63418
# 1963                      66918
# 1964                      69573
# 1965                      76114
# ...                         ...
# 2019                     162677
# 2020                     171243
# 2021                     173929
# 2022                     171608
# 2023                      42140
#
# [63 rows x 1 columns]

# %%
# Plot graph :Alcoholic beverages,  tobacco and cannabis [C12]

Year_Expenses_C12.plot(kind="bar", figsize=(15,5))

# Set a title for the chart
plt.title("Alcoholic beverages,  tobacco and cannabis 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
matplotlib.style.use('fivethirtyeight')
plt.savefig("Year_Expenses_C12.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Communications

# %%
#Communications [C18]
Expenses_C18  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Communications [C18]", ]
Expenses_C18      

Year_Expenses_C18 = Expenses_C18[["YEAR","VALUE"]]
Year_Expenses_C18=Year_Expenses_C18.set_index("YEAR")
Year_Expenses_C18= Year_Expenses_C18.rename(columns={"VALUE":"Communication_Value"})
Year_Expenses_C18
# Out:
#       Communication_Value
# YEAR
# 1961                 4147
# 1962                 4418
# 1963                 4711
# 1964                 5057
# 1965                 5324
# ...                   ...
# 2019               133951
# 2020               138396
# 2021               149066
# 2022               156765
# 2023                41002
#
# [63 rows x 1 columns]

# %%
#Plot Communications 

Year_Expenses_C18.plot(kind="bar", figsize=(15,5),color="b",alpha=0.5)

# Set a title for the chart
plt.title("Communications 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C18.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Clothings

# %%
#Clothing and footwear [C13]
Expenses_C13  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Clothing and footwear [C13]", ]
Expenses_C13

Year_Expenses_C13 = Expenses_C13[["YEAR","VALUE"]]
Year_Expenses_C13=Year_Expenses_C13.set_index("YEAR")
Year_Expenses_C13= Year_Expenses_C13.rename(columns={"VALUE":"Clothing and footwear_Value"})
Year_Expenses_C13
# Out:
#       Clothing and footwear_Value
# YEAR
# 1961                        31637
# 1962                        33765
# 1963                        34746
# 1964                        35842
# 1965                        37640
# ...                           ...
# 2019                       201448
# 2020                       163667
# 2021                       193730
# 2022                       224931
# 2023                        59496
#
# [63 rows x 1 columns]

# %%
#Plot Clothing and footwear [C13]
Year_Expenses_C13.plot(kind="bar", figsize=(9,3),color="green",alpha=0.5)
# Set a title for the chart
plt.title("Clothing and footwear 1961-2023")
plt.ylabel("Value in million dollars")
# Show plot
plt.savefig("Year_Expenses_C13.png")
plt.show()
plt.tight_layout()

# %% [markdown]
# Education

# %%
#Education [C21]
Expenses_C21  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Education [C21]", ]
Expenses_C21

Year_Expenses_C21 = Expenses_C21[["YEAR","VALUE"]]
Year_Expenses_C21=Year_Expenses_C21.set_index("YEAR")
Year_Expenses_C21= Year_Expenses_C21.rename(columns={"VALUE":"Education_Value"})
Year_Expenses_C21
# Out:
#       Education_Value
# YEAR
# 1961             7312
# 1962             7650
# 1963             8242
# 1964             8802
# 1965             9303
# ...               ...
# 2019            77016
# 2020            75572
# 2021            76364
# 2022            79914
# 2023            20224
#
# [63 rows x 1 columns]

# %%
#Plot Education [C21]
Year_Expenses_C21.plot(kind="bar", figsize=(15,5),color="b",alpha=1.0)

# Set a title for the chart
plt.title("Education 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C21.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Food

# %%
#Food and non-alcoholic beverages [C11]
Expenses_C11  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Food and non-alcoholic beverages [C11]", ]
Expenses_C11
Year_Expenses_C11 = Expenses_C11[["YEAR","VALUE"]]
Year_Expenses_C11=Year_Expenses_C11.set_index("YEAR")
Year_Expenses_C11= Year_Expenses_C11.rename(columns={"VALUE":"Food and non alcohol_Value"})
Year_Expenses_C11
# Out:
#       Food and non alcohol_Value
# YEAR
# 1961                      152939
# 1962                      158654
# 1963                      162303
# 1964                      168527
# 1965                      172904
# ...                          ...
# 2019                      417892
# 2020                      449754
# 2021                      447520
# 2022                      431236
# 2023                      106825
#
# [63 rows x 1 columns]

# %%
#Plot Food and non-alcoholic beverages [C11]

Year_Expenses_C11.plot(kind="bar", figsize=(15,5),color="r",alpha=1.0)

# Set a title for the chart
plt.title("Food and non-alcoholic beverages  1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C11.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Food Service

# %%
#Food, beverage and accommodation services [C22]
Expenses_C22  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Food, beverage and accommodation services [C22]", ]
Expenses_C22

Year_Expenses_C22 = Expenses_C22[["YEAR","VALUE"]]
Year_Expenses_C22=Year_Expenses_C22.set_index("YEAR")
Year_Expenses_C22= Year_Expenses_C22.rename(columns={"VALUE":"Food and beverage_Value"})
Year_Expenses_C22
# Out:
#       Food and beverage_Value
# YEAR
# 1961                    84105
# 1962                    88967
# 1963                    90644
# 1964                    93744
# 1965                    98775
# ...                       ...
# 2019                   318419
# 2020                   222441
# 2021                   255966
# 2022                   304513
# 2023                    81599
#
# [63 rows x 1 columns]

# %%
# Plot Food, beverage and accommodation services 1961-2023

Year_Expenses_C22.plot(kind="bar", figsize=(15,5),color="r",alpha=1.0)

# Set a title for the chart
plt.title("Food, beverage and accommodation services 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C22.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Household Equipements ( Furnishing)

# %%
#Furnishings, household equipment and other goods and services related to the dwelling and property [C15]
Expenses_C15  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Furnishings, household equipment and other goods and services related to the dwelling and property [C15]", ]
Expenses_C15

Year_Expenses_C15 = Expenses_C15[["YEAR","VALUE"]]
Year_Expenses_C15=Year_Expenses_C15.set_index("YEAR")
Year_Expenses_C15= Year_Expenses_C15.rename(columns={"VALUE":"Furnishing,household equipments_Value"})
Year_Expenses_C15
# Out:
#       Furnishing,household equipments_Value
# YEAR
# 1961                                  33064
# 1962                                  34661
# 1963                                  35884
# 1964                                  38087
# 1965                                  39596
# ...                                     ...
# 2019                                 261170
# 2020                                 272205
# 2021                                 291442
# 2022                                 281618
# 2023                                  68777
#
# [63 rows x 1 columns]

# %%
#Plot Furnishings, household equipment and other goods and services related to the dwelling and property [C15]

Year_Expenses_C15.plot(kind="bar", figsize=(15,5),color="b",alpha=0.3)

# Set a title for the chart
plt.title("Furnishings, household equipment and other goods and services related to the dwelling and property [C15]")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C15.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Health

# %%
#Health [C16]
Expenses_C16  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Health [C16]", ]
Expenses_C16

Year_Expenses_C16 = Expenses_C16[["YEAR","VALUE"]]
Year_Expenses_C16=Year_Expenses_C16.set_index("YEAR")
Year_Expenses_C16= Year_Expenses_C16.rename(columns={"VALUE":"Health_Value"})
Year_Expenses_C16
# Out:
#       Health_Value
# YEAR
# 1961         29625
# 1962         31486
# 1963         33479
# 1964         34937
# 1965         37125
# ...            ...
# 2019        204621
# 2020        186087
# 2021        201265
# 2022        214867
# 2023         53916
#
# [63 rows x 1 columns]

# %%
#Plot Health [C16]


Year_Expenses_C16.plot(kind="bar", figsize=(15,5),color="r",alpha=0.5)

# Set a title for the chart
plt.title("Health 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C16.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Household final consumption

# %%
#Household final consumption expenditure [C]
Expenses_C  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Household final consumption expenditure [C]", ]
Expenses_C

Year_Expenses_C = Expenses_C[["YEAR","VALUE"]]
Year_Expenses_C=Year_Expenses_C.set_index("YEAR")
Year_Expenses_C= Year_Expenses_C.rename(columns={"VALUE":"Household final consumption_Value"})
Year_Expenses_C
# Out:
#       Household final consumption_Value
# YEAR
# 1961                             749193
# 1962                             786674
# 1963                             819044
# 1964                             863168
# 1965                             912926
# ...                                 ...
# 2019                            4738960
# 2020                            4439946
# 2021                            4666014
# 2022                            4887941
# 2023                            1248630
#
# [63 rows x 1 columns]

# %%
# Plot Household final consumption expenditure 1961-2023[C]

Year_Expenses_C.plot(kind="bar", figsize=(15,5),color="y",alpha=1.0)

# Set a title for the chart
plt.title("Household final consumption expenditure 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Housing, Utility

# %%
#Housing, water, electricity, gas and other fuels [C14]
Expenses_C14  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Housing, water, electricity, gas and other fuels [C14]", ]
Expenses_C14

Year_Expenses_C14 = Expenses_C14[["YEAR","VALUE"]]
Year_Expenses_C14=Year_Expenses_C14.set_index("YEAR")
Year_Expenses_C14= Year_Expenses_C14.rename(columns={"VALUE":"Water and Fuels_Value"})
Year_Expenses_C14
# Out:
#       Water and Fuels_Value
# YEAR
# 1961                 247124
# 1962                 255494
# 1963                 264508
# 1964                 274751
# 1965                 284512
# ...                     ...
# 2019                1135754
# 2020                1165092
# 2021                1198077
# 2022                1229010
# 2023                 310225
#
# [63 rows x 1 columns]

# %%
#Plot Housing, water, electricity, gas and other fuels [C14]

Year_Expenses_C14.plot(kind="bar", figsize=(15,5),color="g",alpha=0.2)

# Set a title for the chart
plt.title("Housing, water, electricity, gas and other fuels 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C14.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Insurance

# %%
#Insurance and financial services [C23]
Expenses_C23  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Insurance and financial services [C23]", ]
Expenses_C23

Year_Expenses_C23 = Expenses_C23[["YEAR","VALUE"]]
Year_Expenses_C23=Year_Expenses_C23.set_index("YEAR")
Year_Expenses_C23= Year_Expenses_C23.rename(columns={"VALUE":"Insurance and financial services_Value"})
Year_Expenses_C23
# Out:
#       Insurance and financial services_Value
# YEAR
# 1961                                   33956
# 1962                                   35294
# 1963                                   37504
# 1964                                   38951
# 1965                                   40992
# ...                                      ...
# 2019                                  455979
# 2020                                  468283
# 2021                                  503981
# 2022                                  509040
# 2023                                  124753
#
# [63 rows x 1 columns]

# %%
# Plot Insurance and financial services [C23]
Year_Expenses_C23.plot(kind="bar", figsize=(15,5),color="orange",alpha=0.5)

# Set a title for the chart
plt.title("Insurance and financial services 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C23.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Miscellaneous goods

# %%
#Miscellaneous goods and services [C24]
Expenses_C24  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Miscellaneous goods and services [C24]", ]
Expenses_C24


Year_Expenses_C24 = Expenses_C24[["YEAR","VALUE"]]
Year_Expenses_C24=Year_Expenses_C24.set_index("YEAR")
Year_Expenses_C24= Year_Expenses_C24.rename(columns={"VALUE":"Miscellaneous goods and services_Value"})
Year_Expenses_C24
# Out:
#       Miscellaneous goods and services_Value
# YEAR
# 1961                                   33266
# 1962                                   35251
# 1963                                   37091
# 1964                                   39487
# 1965                                   42256
# ...                                      ...
# 2019                                  245850
# 2020                                  222761
# 2021                                  236481
# 2022                                  255727
# 2023                                   64466
#
# [63 rows x 1 columns]

# %%
#PlotMiscellaneous goods and service [C24]


Year_Expenses_C24.plot(kind="bar", figsize=(15,5),color="orange",alpha=1.0)

# Set a title for the chart
plt.title("Miscellaneous goods and services 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C24.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Net expenditure abroad

# %%
#Net expenditure abroad [C25]
Expenses_C25  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Net expenditure abroad [C25]", ]
Expenses_C25


Year_Expenses_C25 = Expenses_C25[["YEAR","VALUE"]]
Year_Expenses_C25=Year_Expenses_C25.set_index("YEAR")
Year_Expenses_C25= Year_Expenses_C25.rename(columns={"VALUE":"Net expenditure abroad_Value"})
Year_Expenses_C25
# Out:
#       Net expenditure abroad_Value
# YEAR
# 1961                         -4070
# 1962                         -9763
# 1963                        -12350
# 1964                        -11084
# 1965                        -11906
# ...                            ...
# 2019                         14260
# 2020                        -10996
# 2021                        -27792
# 2022                           492
# 2023                          1504
#
# [63 rows x 1 columns]

# %%
#Plot Net expenditure abroad [C25]


Year_Expenses_C25.plot(kind="bar", figsize=(15,5),color="pink",alpha=1.0)

# Set a title for the chart
plt.title("Net expenditure abroad 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C25.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Recreation

# %%
#Recreation and culture [C19]
Expenses_C19  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Recreation and culture [C19]", ]
Expenses_C19

Year_Expenses_C19 = Expenses_C19[["YEAR","VALUE"]]
Year_Expenses_C19=Year_Expenses_C19.set_index("YEAR")
Year_Expenses_C19= Year_Expenses_C19.rename(columns={"VALUE":"Recreation and culture_Value"})
Year_Expenses_C19
# Out:
#       Recreation and culture_Value
# YEAR
# 1961                         18676
# 1962                         20220
# 1963                         20959
# 1964                         22490
# 1965                         24941
# ...                            ...
# 2019                        384171
# 2020                        355971
# 2021                        384287
# 2022                        407300
# 2023                        104858
#
# [63 rows x 1 columns]

# %%
#Plot Recreation and culture[C19]


Year_Expenses_C25.plot(kind="bar", figsize=(15,5),color="pink",alpha=0.9)

# Set a title for the chart
plt.title("Recreation and culture 1961-2023")

plt.ylabel("Value in million dollars")

# Show plot
plt.savefig("Year_Expenses_C19.png", bbox_inches="tight")
plt.show()
plt.tight_layout()

# %% [markdown]
# Transport

# %%
#Transport [C17]
Expenses_C17  = rename_clean_df.loc[rename_clean_df["Expenditures_(Millions_Dallars)"] == "Transport [C17]", ]
Expenses_C17


Year_Expenses_C17 = Expenses_C17[["YEAR","VALUE"]]
Year_Expenses_C17=Year_Expenses_C17.set_index("YEAR")
Year_Expenses_C17= Year_Expenses_C17.rename(columns={"VALUE":"Transport_Value"})
Year_Expenses_C17
# Out:
#       Transport_Value
# YEAR
# 1961            83298
# 1962            91931
# 1963           100714
# 1964           111458
# 1965           123554
# ...               ...
# 2019           734179
# 2020           579575
# 2021           614301
# 2022           651906
# 2023           175774
#
# [63 rows x 1 columns]

# %% [markdown]
# Overall Line Graph

# %%
# Merging all the data into one, to create a comaprison of all expenses
items_merge = Year_Expenses_C12.join(Year_Expenses_C13, how = "outer")
items_merge = items_merge.join(Year_Expenses_C18, on="YEAR", how = "outer")
items_merge = items_merge.join(Year_Expenses_C21, on="YEAR" ,how = "outer")
items_merge = items_merge.join(Year_Expenses_C11, on="YEAR" ,how = "outer")
items_merge = items_merge.join(Year_Expenses_C22, on="YEAR" ,how = "outer")
items_merge= items_merge.join(Year_Expenses_C15, on="YEAR" ,how = "outer")
items_merge =items_merge.join(Year_Expenses_C16, on="YEAR" ,how = "outer")
#items_merge = items_merge.join(Year_Expenses_C, on="YEAR",how = "outer")
items_merge = items_merge.join(Year_Expenses_C14, on="YEAR",how = "outer")
items_merge = items_merge.join(Year_Expenses_C23, on="YEAR",how = "outer")
items_merge = items_merge.join(Year_Expenses_C24, on="YEAR",how = "outer")
items_merge = items_merge.join(Year_Expenses_C25, on="YEAR",how = "outer")
items_merge = items_merge.join(Year_Expenses_C19, on="YEAR",how = "outer")
#items_merge = items_merge.join(Year_Expenses_C17, on="YEAR",how = "outer")
items_merge = pd.merge(items_merge,Year_Expenses_C17,on="YEAR")
items_merge.head(20)
# Out:
#       Alcoholic beverages_Value  Clothing and footwear_Value  \
# YEAR
# 1961                      59899                        31637
# 1962                      63418                        33765
# 1963                      66918                        34746
# 1964                      69573                        35842
# 1965                      76114                        37640
# 1966                      82131                        39326
# 1967                      88177                        40369
# 1968                      90585                        41570
# 1969                      95946                        43823
# 1970                     104988                        44906
# 1971                     113805                        47412
# 1972                     121926                        51593
# 1973                     129781                        53885
# 1974                     136671                        57194
# 1975                     141983                        61235
# 1976                     143640                        65978
# 1977                     147381                        68365
# 1978                     149977                        71468
# 1979                     153532                        74519
# 1980                     156521                        74671
#
#       Communication_Value  Education_Value  Food and non alcohol_Value  \
# YEAR
# 1961                 4147             7312                      152939
# 1962                 4418             7650                      158654
# 1963                 4711             8242                      162303
# 1964                 5057             8802                      168527
# 1965                 5324             9303                      172904
# 1966                 5834            10024                      176430
# 1967                 6386            10420                      183444
# 1968                 6793            10874                      184278
# 1969                 7325            11818                      188601
# 1970                 7812            12410                      194433
# 1971                 8608            13742                      199112
# 1972                 9184            14314                      203315
# 1973                10059            15948                      208549
# 1974                11199            17661                      213597
# 1975                12359            19707                      216185
# 1976                13958            21281                      220368
# 1977                14435            22951                      222405
# 1978                15662            23157                      224556
# 1979                17159            24480                      226485
# 1980                18830            26210                      228468
#
#       Food and beverage_Value  Furnishing,household equipments_Value  \
# YEAR
# 1961                    84105                                  33064
# 1962                    88967                                  34661
# 1963                    90644                                  35884
# 1964                    93744                                  38087
# 1965                    98775                                  39596
# 1966                   101656                                  42515
# 1967                   107720                                  44307
# 1968                   109204                                  46419
# 1969                   113834                                  48823
# 1970                   116897                                  50106
# 1971                   123287                                  53276
# 1972                   131464                                  59702
# 1973                   139779                                  68860
# 1974                   144987                                  75821
# 1975                   147491                                  77937
# 1976                   158776                                  81522
# 1977                   162822                                  81978
# 1978                   169991                                  84948
# 1979                   170678                                  89720
# 1980                   174382                                  91995
#
#       Health_Value  Water and Fuels_Value  \
# YEAR
# 1961         29625                 247124
# 1962         31486                 255494
# 1963         33479                 264508
# 1964         34937                 274751
# 1965         37125                 284512
# 1966         40117                 293010
# 1967         42514                 303213
# 1968         45213                 313506
# 1969         43189                 325734
# 1970         35930                 338264
# 1971         33425                 348475
# 1972         35730                 354182
# 1973         38862                 354882
# 1974         39809                 361327
# 1975         41878                 365109
# 1976         43735                 371586
# 1977         46750                 374655
# 1978         49366                 379582
# 1979         49248                 384732
# 1980         51700                 391639
#
#       Insurance and financial services_Value  \
# YEAR
# 1961                                   33956
# 1962                                   35294
# 1963                                   37504
# 1964                                   38951
# 1965                                   40992
# 1966                                   42982
# 1967                                   45883
# 1968                                   49563
# 1969                                   53564
# 1970                                   54511
# 1971                                   55785
# 1972                                   59891
# 1973                                   64085
# 1974                                   66303
# 1975                                   67897
# 1976                                   71925
# 1977                                   77545
# 1978                                   82166
# 1979                                   89219
# 1980                                   93815
#
#       Miscellaneous goods and services_Value  Net expenditure abroad_Value  \
# YEAR
# 1961                                   33266                         -4070
# 1962                                   35251                         -9763
# 1963                                   37091                        -12350
# 1964                                   39487                        -11084
# 1965                                   42256                        -11906
# 1966                                   44584                        -12230
# 1967                                   46500                        -29358
# 1968                                   47295                        -12556
# 1969                                   49810                         -9825
# 1970                                   51330                        -11327
# 1971                                   54032                        -11228
# 1972                                   58106                         -9336
# 1973                                   62297                         -9750
# 1974                                   66860                         -8419
# 1975                                   68620                         -1639
# 1976                                   72915                          6903
# 1977                                   77740                          8833
# 1978                                   79683                          2215
# 1979                                   81212                        -11336
# 1980                                   82502                        -12126
#
#       Recreation and culture_Value  Transport_Value
# YEAR
# 1961                         18676            83298
# 1962                         20220            91931
# 1963                         20959           100714
# 1964                         22490           111458
# 1965                         24941           123554
# 1966                         27394           131460
# 1967                         30917           137377
# 1968                         32781           145421
# 1969                         36383           152384
# 1970                         37971           147546
# 1971                         43273           163053
# 1972                         50176           181317
# 1973                         57522           206740
# 1974                         65343           213466
# 1975                         68957           229473
# 1976                         76618           239066
# 1977                         79272           247330
# 1978                         84893           258026
# 1979                         89016           267687
# 1980                         91616           264039

# %%
items_merge.plot(figsize=(12,10),xlim=(1961,2022))
plt.title("Household final consumption expenditure, quarterly, Canada (x 1,000,000)")
plt.xlabel("Years")
plt.ylabel("Value in million dollars")
plt.legend(loc = 'upper left')
# plt.ylabel("Value in million dollars")
plt.savefig("items_merge.png")
plt.show()

# %% [markdown]
# # Preparing for pre/post covid data

# %%
# Picking only the years i want from the data-k
filter_data = clean_df.loc[(clean_df["REF_YEAR"] == 2022)|
                           (clean_df["REF_YEAR"] == 2021)|
                           (clean_df["REF_YEAR"] == 2020)|
                           (clean_df["REF_YEAR"] == 2019)|
                           (clean_df["REF_YEAR"] == 2018)
]

# %%
# Checking the data-k
filter_data
# Out:
#      REF_YEAR                                         Estimates  UOM_ID  \
# 855      2018  Alcoholic beverages,  tobacco and cannabis [C12]     324
# 856      2018                       Clothing and footwear [C13]     324
# 857      2018                              Communications [C18]     324
# 858      2018                                   Education [C21]     324
# 859      2018            Food and non-alcoholic beverages [C11]     324
# ..        ...                                               ...     ...
# 925      2022            Insurance and financial services [C23]     324
# 926      2022            Miscellaneous goods and services [C24]     324
# 927      2022                      Net expenditure abroad [C25]     324
# 928      2022                      Recreation and culture [C19]     324
# 929      2022                                   Transport [C17]     324
#
#      SCALAR_ID   VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# 855         24  162741     0.0     0.0         0.0         0
# 856         24  199117     0.0     0.0         0.0         0
# 857         24  127348     0.0     0.0         0.0         0
# 858         24   74365     0.0     0.0         0.0         0
# 859         24  416591     0.0     0.0         0.0         0
# ..         ...     ...     ...     ...         ...       ...
# 925         24  509040     0.0     0.0         0.0         0
# 926         24  255727     0.0     0.0         0.0         0
# 927         24     492     0.0     0.0         0.0         0
# 928         24  407300     0.0     0.0         0.0         0
# 929         24  651906     0.0     0.0         0.0         0
#
# [75 rows x 9 columns]

# %%
# Getting rid of the partial strings that i don't want-k
filter_data['Estimates'] = filter_data['Estimates'].map(lambda x: x.rstrip('[]C0123456789'))

# %%
#checking the data
filter_data.head()
# Out:
#      REF_YEAR                                    Estimates  UOM_ID  SCALAR_ID  \
# 855      2018  Alcoholic beverages,  tobacco and cannabis      324         24
# 856      2018                       Clothing and footwear      324         24
# 857      2018                              Communications      324         24
# 858      2018                                   Education      324         24
# 859      2018            Food and non-alcoholic beverages      324         24
#
#       VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# 855  162741     0.0     0.0         0.0         0
# 856  199117     0.0     0.0         0.0         0
# 857  127348     0.0     0.0         0.0         0
# 858   74365     0.0     0.0         0.0         0
# 859  416591     0.0     0.0         0.0         0

# %%
# Making Estimate the index
filter_data.set_index("Estimates", inplace=True)

# %%
# Checking the data
filter_data.tail(20)
# Out:
#                                                     REF_YEAR  UOM_ID  \
# Estimates
# Insurance and financial services                        2021     324
# Miscellaneous goods and services                        2021     324
# Net expenditure abroad                                  2021     324
# Recreation and culture                                  2021     324
# Transport                                               2021     324
# Alcoholic beverages,  tobacco and cannabis              2022     324
# Clothing and footwear                                   2022     324
# Communications                                          2022     324
# Education                                               2022     324
# Food and non-alcoholic beverages                        2022     324
# Food, beverage and accommodation services               2022     324
# Furnishings, household equipment and other good...      2022     324
# Health                                                  2022     324
# Household final consumption expenditure                 2022     324
# Housing, water, electricity, gas and other fuels        2022     324
# Insurance and financial services                        2022     324
# Miscellaneous goods and services                        2022     324
# Net expenditure abroad                                  2022     324
# Recreation and culture                                  2022     324
# Transport                                               2022     324
#
#                                                     SCALAR_ID    VALUE  \
# Estimates
# Insurance and financial services                           24   503981
# Miscellaneous goods and services                           24   236481
# Net expenditure abroad                                     24   -27792
# Recreation and culture                                     24   384287
# Transport                                                  24   614301
# Alcoholic beverages,  tobacco and cannabis                 24   171608
# Clothing and footwear                                      24   224931
# Communications                                             24   156765
# Education                                                  24    79914
# Food and non-alcoholic beverages                           24   431236
# Food, beverage and accommodation services                  24   304513
# Furnishings, household equipment and other good...         24   281618
# Health                                                     24   214867
# Household final consumption expenditure                    24  4887941
# Housing, water, electricity, gas and other fuels           24  1229010
# Insurance and financial services                           24   509040
# Miscellaneous goods and services                           24   255727
# Net expenditure abroad                                     24      492
# Recreation and culture                                     24   407300
# Transport                                                  24   651906
#
#                                                     STATUS  SYMBOL  \
# Estimates
# Insurance and financial services                       0.0     0.0
# Miscellaneous goods and services                       0.0     0.0
# Net expenditure abroad                                 0.0     0.0
# Recreation and culture                                 0.0     0.0
# Transport                                              0.0     0.0
# Alcoholic beverages,  tobacco and cannabis             0.0     0.0
# Clothing and footwear                                  0.0     0.0
# Communications                                         0.0     0.0
# Education                                              0.0     0.0
# Food and non-alcoholic beverages                       0.0     0.0
# Food, beverage and accommodation services              0.0     0.0
# Furnishings, household equipment and other good...     0.0     0.0
# Health                                                 0.0     0.0
# Household final consumption expenditure                0.0     0.0
# Housing, water, electricity, gas and other fuels       0.0     0.0
# Insurance and financial services                       0.0     0.0
# Miscellaneous goods and services                       0.0     0.0
# Net expenditure abroad                                 0.0     0.0
# Recreation and culture                                 0.0     0.0
# Transport                                              0.0     0.0
#
#                                                     TERMINATED  DECIMALS
# Estimates
# Insurance and financial services                           0.0         0
# Miscellaneous goods and services                           0.0         0
# Net expenditure abroad                                     0.0         0
# Recreation and culture                                     0.0         0
# Transport                                                  0.0         0
# Alcoholic beverages,  tobacco and cannabis                 0.0         0
# Clothing and footwear                                      0.0         0
# Communications                                             0.0         0
# Education                                                  0.0         0
# Food and non-alcoholic beverages                           0.0         0
# Food, beverage and accommodation services                  0.0         0
# Furnishings, household equipment and other good...         0.0         0
# Health                                                     0.0         0
# Household final consumption expenditure                    0.0         0
# Housing, water, electricity, gas and other fuels           0.0         0
# Insurance and financial services                           0.0         0
# Miscellaneous goods and services                           0.0         0
# Net expenditure abroad                                     0.0         0
# Recreation and culture                                     0.0         0
# Transport                                                  0.0         0

# %%
# Checking the index, checking for spaces, for locating later.
filter_data.index.unique()
# Out:
# Index(['Alcoholic beverages,  tobacco and cannabis ', 'Clothing and footwear ',
#        'Communications ', 'Education ', 'Food and non-alcoholic beverages ',
#        'Food, beverage and accommodation services ',
#        'Furnishings, household equipment and other goods and services related to the dwelling and property ',
#        'Health ', 'Household final consumption expenditure ',
#        'Housing, water, electricity, gas and other fuels ',
#        'Insurance and financial services ',
#        'Miscellaneous goods and services ', 'Net expenditure abroad ',
#        'Recreation and culture ', 'Transport '],
#       dtype='object', name='Estimates')

# %%
filter_data_net = filter_data

# %%
# Dropping the HouseHold Final Consumption as it is just the sum of all expense.
filter_data = filter_data.drop(['Household final consumption expenditure '], axis=0)

# %%
# Renaming one of the index, since it is too long.
filter_data.rename(index={'Furnishings, household equipment and other goods and services related to the dwelling and property ':"Household Equipment"}, inplace= True)

# %%
#2018
data2018 = filter_data.loc[filter_data["REF_YEAR"]== 2018]
#2019
data2019 = filter_data.loc[filter_data["REF_YEAR"]== 2019]
#2020
data2020 = filter_data.loc[filter_data["REF_YEAR"]== 2020]
#2021
data2021 = filter_data.loc[filter_data["REF_YEAR"]== 2021]
#2022
data2022 = filter_data.loc[filter_data["REF_YEAR"]== 2022]

# %%
# Renaming the VALUE columns according to the year of the data 
data2022.rename({'VALUE': '2022V'},axis='columns', inplace= True)

data2021.rename({'VALUE': '2021V'},axis='columns', inplace= True)

data2020.rename({'VALUE': '2020V'},axis='columns', inplace= True)

data2019.rename({'VALUE': '2019V'},axis='columns', inplace= True)

data2018.rename({'VALUE': '2018V'},axis='columns', inplace= True)

# Picking only the data i want
df2022 = data2022[["2022V"]]

df2021 = data2021[["2021V"]]

df2020 = data2020[["2020V"]]

df2019 = data2019[["2019V"]]

df2018 = data2018[["2018V"]]

# %%
# Merging all the data into one, to create a comaprison of Year 2018 ~2022
merge = df2022.join(df2021, how = "outer")
merge = merge.join(df2020, how = "outer")
merge = merge.join(df2019, how = "outer")
merge = merge.join(df2018, how = "outer")

# %%
# Visualizing the data
merge
# Out:
#                                                      2022V    2021V    2020V  \
# Estimates
# Alcoholic beverages,  tobacco and cannabis          171608   173929   171243
# Clothing and footwear                               224931   193730   163667
# Communications                                      156765   149066   138396
# Education                                            79914    76364    75572
# Food and non-alcoholic beverages                    431236   447520   449754
# Food, beverage and accommodation services           304513   255966   222441
# Household Equipment                                 281618   291442   272205
# Health                                              214867   201265   186087
# Housing, water, electricity, gas and other fuels   1229010  1198077  1165092
# Insurance and financial services                    509040   503981   468283
# Miscellaneous goods and services                    255727   236481   222761
# Net expenditure abroad                                 492   -27792   -10996
# Recreation and culture                              407300   384287   355971
# Transport                                           651906   614301   579575
#
#                                                      2019V    2018V
# Estimates
# Alcoholic beverages,  tobacco and cannabis          162677   162741
# Clothing and footwear                               201448   199117
# Communications                                      133951   127348
# Education                                            77016    74365
# Food and non-alcoholic beverages                    417892   416591
# Food, beverage and accommodation services           318419   311833
# Household Equipment                                 261170   254043
# Health                                              204621   199588
# Housing, water, electricity, gas and other fuels   1135754  1109154
# Insurance and financial services                    455979   440766
# Miscellaneous goods and services                    245850   238631
# Net expenditure abroad                               14260    24608
# Recreation and culture                              384171   382357
# Transport                                           734179   735217

# %%
#Checking for all the index
merge.index
# Out:
# Index(['Alcoholic beverages,  tobacco and cannabis ', 'Clothing and footwear ',
#        'Communications ', 'Education ', 'Food and non-alcoholic beverages ',
#        'Food, beverage and accommodation services ', 'Household Equipment',
#        'Health ', 'Housing, water, electricity, gas and other fuels ',
#        'Insurance and financial services ',
#        'Miscellaneous goods and services ', 'Net expenditure abroad ',
#        'Recreation and culture ', 'Transport '],
#       dtype='object', name='Estimates')

# %% [markdown]
# Closer look of the effect of Covid

# %%
matplotlib.style.use('fivethirtyeight')

# %%
# Bar chart of year 2018 ~ 2022 expenditure

plot1 =merge.plot(kind = "barh" ,xlabel= " Expenses ( in millions)", width = 0.8, figsize=(10,15), title= 'Pre/Post Covid Expenses')
matplotlib.style.use('fivethirtyeight')
plt.savefig("Covid_Expenses.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# Category that did not change after covid:
# Insurances and financial services
# Housing and Utilities
# Communications

# %%
# Checking the data
merge
# Out:
#                                                      2022V    2021V    2020V  \
# Estimates
# Alcoholic beverages,  tobacco and cannabis          171608   173929   171243
# Clothing and footwear                               224931   193730   163667
# Communications                                      156765   149066   138396
# Education                                            79914    76364    75572
# Food and non-alcoholic beverages                    431236   447520   449754
# Food, beverage and accommodation services           304513   255966   222441
# Household Equipment                                 281618   291442   272205
# Health                                              214867   201265   186087
# Housing, water, electricity, gas and other fuels   1229010  1198077  1165092
# Insurance and financial services                    509040   503981   468283
# Miscellaneous goods and services                    255727   236481   222761
# Net expenditure abroad                                 492   -27792   -10996
# Recreation and culture                              407300   384287   355971
# Transport                                           651906   614301   579575
#
#                                                      2019V    2018V
# Estimates
# Alcoholic beverages,  tobacco and cannabis          162677   162741
# Clothing and footwear                               201448   199117
# Communications                                      133951   127348
# Education                                            77016    74365
# Food and non-alcoholic beverages                    417892   416591
# Food, beverage and accommodation services           318419   311833
# Household Equipment                                 261170   254043
# Health                                              204621   199588
# Housing, water, electricity, gas and other fuels   1135754  1109154
# Insurance and financial services                    455979   440766
# Miscellaneous goods and services                    245850   238631
# Net expenditure abroad                               14260    24608
# Recreation and culture                              384171   382357
# Transport                                           734179   735217

# %%
#Picking Education
edu = merge.iloc[[3]]
edu
# Changing the order
edu = edu[['2018V','2019V','2020V','2021V','2022V']]

# %%
edu2 =edu.transpose()

edu2
# Out:
# Estimates  Education
# 2018V           74365
# 2019V           77016
# 2020V           75572
# 2021V           76364
# 2022V           79914

# %%
#Plotting
edu2.plot(kind = "bar" ,xlabel= "Years", title= 'Education')

plt.savefig("Education_Covid.png", bbox_inches="tight")

# %%
# Checking for all unique index
filter_data_net.index.unique()
# Out:
# Index(['Alcoholic beverages,  tobacco and cannabis ', 'Clothing and footwear ',
#        'Communications ', 'Education ', 'Food and non-alcoholic beverages ',
#        'Food, beverage and accommodation services ',
#        'Furnishings, household equipment and other goods and services related to the dwelling and property ',
#        'Health ', 'Household final consumption expenditure ',
#        'Housing, water, electricity, gas and other fuels ',
#        'Insurance and financial services ',
#        'Miscellaneous goods and services ', 'Net expenditure abroad ',
#        'Recreation and culture ', 'Transport '],
#       dtype='object', name='Estimates')

# %%
# Picking the filter i want
final_expense = filter_data_net.loc['Household final consumption expenditure ']

final_expense
# Out:
#                                           REF_YEAR  UOM_ID  SCALAR_ID  \
# Estimates
# Household final consumption expenditure       2018     324         24
# Household final consumption expenditure       2019     324         24
# Household final consumption expenditure       2020     324         24
# Household final consumption expenditure       2021     324         24
# Household final consumption expenditure       2022     324         24
#
#                                             VALUE  STATUS  SYMBOL  TERMINATED  \
# Estimates
# Household final consumption expenditure   4669505     0.0     0.0         0.0
# Household final consumption expenditure   4738960     0.0     0.0         0.0
# Household final consumption expenditure   4439946     0.0     0.0         0.0
# Household final consumption expenditure   4666014     0.0     0.0         0.0
# Household final consumption expenditure   4887941     0.0     0.0         0.0
#
#                                           DECIMALS
# Estimates
# Household final consumption expenditure          0
# Household final consumption expenditure          0
# Household final consumption expenditure          0
# Household final consumption expenditure          0
# Household final consumption expenditure          0

# %%
#Setting the Year as the index for easier graph
final_expense.set_index('REF_YEAR')
# Out:
#           UOM_ID  SCALAR_ID    VALUE  STATUS  SYMBOL  TERMINATED  DECIMALS
# REF_YEAR
# 2018         324         24  4669505     0.0     0.0         0.0         0
# 2019         324         24  4738960     0.0     0.0         0.0         0
# 2020         324         24  4439946     0.0     0.0         0.0         0
# 2021         324         24  4666014     0.0     0.0         0.0         0
# 2022         324         24  4887941     0.0     0.0         0.0         0

# %% [markdown]
# Regression Covid

# %%
# Define a function to create Linear Regression plots
def linger_regression_plot(x,y,title,location):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,location,fontsize=18,color="red")
    plt.xlabel('Years')
    plt.title('Regression Covid')
    plt.ylabel(title)
    plt.xticks(x,rotation = 'vertical')
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
#Defining x and y for plots
x = final_expense['REF_YEAR']
y = final_expense['VALUE']

# %%
#Plotting a regression 
linger_regression_plot(x, y, "Final Consumption", (2019,4569505))

plt.savefig("Regression_Covid.png", bbox_inches="tight")
# Out:
# The r-value is: 0.12656170020302893

# %% [markdown]
# Regression Overall

# %%
def linger_regression_plot2(x,y,title,location):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,location,fontsize=18,color="red")
    plt.xlabel('Years')
    
    plt.title('Household final consumption')
    plt.ylabel(title)
    plt.xticks(x[::5],rotation = 'vertical')
    plt.xlim(1960,2022.5)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
x1 = Year_Expenses_C.index
y2 = Year_Expenses_C['Household final consumption_Value']

# %%
linger_regression_plot2(x1, y2, 'Household final consumption', (1960,4569505), )
plt.savefig("Regression_overall.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.8573252393152558

# %% [markdown]
# -    As we can see, there is clearly an upward linear relationship with r-value of 0.8573

# %%
#checking the expenses data for how many rows
Year_Expenses_C
# Out:
#       Household final consumption_Value
# YEAR
# 1961                             749193
# 1962                             786674
# 1963                             819044
# 1964                             863168
# 1965                             912926
# ...                                 ...
# 2019                            4738960
# 2020                            4439946
# 2021                            4666014
# 2022                            4887941
# 2023                            1248630
#
# [63 rows x 1 columns]

# %%
#Filtering the data for pre covid
pre_covid_expense = Year_Expenses_C.iloc[54:58]
post_covid_expense = Year_Expenses_C.iloc[58:62]

# %%
# Setting up for T-Test
pop1 =pre_covid_expense.reset_index(drop=True)
pop2 = post_covid_expense.reset_index(drop=True)

# %%
# Using course material to help with graph
def gendata(loc1=0, loc2=0):
    population1 = pop1
    population2 = pop2

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="pre_covid")
    plt.scatter(range(len(population2)), population2, label="post_covid")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="pre_covid")
    plt.hist(population2, 10, density=True, alpha=0.7, label="post_covid")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %% [markdown]
# Scatter Covid

# %%
# Scatter Plot of Data
plt.subplot(2, 1, 1)
plt.scatter(range(len(pop1)), pop1, label="pre_covid")
plt.scatter(range(len(pop2)), pop2, label="post_covid")
plt.title(" Scatter Covid")
plt.xlabel("Numbers")
plt.ylabel("Expense(millions)")
plt.savefig("Scatter_Covid.png", bbox_inches="tight")
plt.legend(loc = 'center left')

# %% [markdown]
# -	Null Hypothesis— Consumer spending habit stayed the same.
#
# -	Alternative Hypothesis-- Consumer spending habit changed after covid.

# %%
# Assuming they do not have equal variance 
stats.ttest_ind(pop1, pop2, equal_var=True)
# Out:
# Ttest_indResult(statistic=array([-1.66144442]), pvalue=array([0.14768876]))

# %% [markdown]
# ## Pvaule > 0.05 so we have failed to reject the Null Hypothesis.

# %%
#Pvaule > 0.05 so we have failed to reject the Null Hypothesis.
